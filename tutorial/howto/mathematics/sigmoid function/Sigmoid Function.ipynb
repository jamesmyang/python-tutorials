# %% [markdown]
# # Sigmoid Function
# https://www.learndatasci.com/glossary/sigmoid-function/

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def d_sigmoid(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
import numpy as np

# create data
x = np.linspace(-10, 10, 100)

# get sigmoid output
y = sigmoid(x)

# get derivative of sigmoid
d = d_sigmoid(x)

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")

fig = plt.figure(figsize=(16, 9))

plt.plot(x, y, c="lightgreen", linewidth=3.0, label="$\sigma(x)$")
plt.plot(x, d, c="lightblue", linewidth=3.0, label="$\\frac{d}{dx} \sigma(x)$")

plt.legend(prop={'size': 20})
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jyang\AppData\Local\Temp\ipykernel_41372\2497068050.py:6: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y, c="lightgreen", linewidth=3.0, label="$\sigma(x)$")
# C:\Users\jyang\AppData\Local\Temp\ipykernel_41372\2497068050.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, d, c="lightblue", linewidth=3.0, label="$\\frac{d}{dx} \sigma(x)$")
