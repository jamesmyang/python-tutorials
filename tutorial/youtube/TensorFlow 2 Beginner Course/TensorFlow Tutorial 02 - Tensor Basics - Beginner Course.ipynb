# %% [markdown]
# # TensorFlow Tutorial 02 - Tensor Basics - Beginner Course
# https://www.youtube.com/watch?v=PcstG8qiObc&list=PLqnslRFeH2Uqfv1Vz3DqeQfy0w20ldbaV&index=5

# %%
import os
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.16.1
