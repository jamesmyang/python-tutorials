# %% [markdown]
# # Python - Tuple Exercises
# https://www.w3schools.com/python/python_tuples_exercises.asp

# %%
thistuple = (1, 3, 7, 7, 5, 4, 6, 8, 5)
thattuple = (1, 3, 7, 7, 5, 4, 6, 8, 5)

x = thistuple == thattuple

print(x)
# Out:
# True
